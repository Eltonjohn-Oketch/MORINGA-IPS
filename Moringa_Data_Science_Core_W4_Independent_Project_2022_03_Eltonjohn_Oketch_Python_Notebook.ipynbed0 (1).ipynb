# %% [markdown]
# # **WEEK 4 : HYPOTHESIS TESTING AFTER UNIVARIATE AND BIVARIATE ANALYSIS.**

# %% [markdown]
# # 1.0 Importing Libraries

# %%
# Importing Pandas
import pandas as pd
# Importing Numpy
import numpy as np
# Importing Matplotlib
import matplotlib.pyplot as plt
# Importing Seaborn
import seaborn as sns

# %% [markdown]
# # 1.2 Loading the dataset

# %%
# Step 1.2: Loading our Dataset

df= pd.read_csv("http://bit.ly/DSCoreAutolibDataset")

# Previewing the dataset

df.head()
# Out:
#    Postal code      date  n_daily_data_points  dayOfWeek day_type  \
# 0        75001  1/1/2018                 1440          0  weekday
# 1        75001  1/2/2018                 1438          1  weekday
# 2        75001  1/3/2018                 1439          2  weekday
# 3        75001  1/4/2018                 1320          3  weekday
# 4        75001  1/5/2018                 1440          4  weekday
#
#    BlueCars_taken_sum  BlueCars_returned_sum  Utilib_taken_sum  \
# 0                 110                    103                 3
# 1                  98                     94                 1
# 2                 138                    139                 0
# 3                 104                    104                 2
# 4                 114                    117                 3
#
#    Utilib_returned_sum  Utilib_14_taken_sum  Utilib_14_returned_sum  \
# 0                    2                   10                       9
# ...

# %% [markdown]
# # 1.2 UNIVARIATES ANALYSIS

# %% [markdown]
# # 1.2.1 Data Understanding

# %%
#Lets preview the first 10 rows of the dataset

df.head(10)
# Out:
#    Postal code       date  n_daily_data_points  dayOfWeek day_type  \
# 0        75001   1/1/2018                 1440          0  weekday
# 1        75001   1/2/2018                 1438          1  weekday
# 2        75001   1/3/2018                 1439          2  weekday
# 3        75001   1/4/2018                 1320          3  weekday
# 4        75001   1/5/2018                 1440          4  weekday
# 5        75001   1/6/2018                 1437          5  weekend
# 6        75001   1/7/2018                 1440          6  weekend
# 7        75001   1/8/2018                 1438          0  weekday
# 8        75001   1/9/2018                 1439          1  weekday
# 9        75001  1/10/2018                 1440          2  weekday
#
#    BlueCars_taken_sum  BlueCars_returned_sum  Utilib_taken_sum  \
# 0                 110                    103                 3
# 1                  98                     94                 1
# ...

# %%
#Lets preview the last 10 rows of the dataset

df.tail(10)
# Out:
#        Postal code       date  n_daily_data_points  dayOfWeek day_type  \
# 16075        95880  6/10/2018                 1440          6  weekend
# 16076        95880  6/11/2018                 1440          0  weekday
# 16077        95880  6/12/2018                 1439          1  weekday
# 16078        95880  6/13/2018                 1440          2  weekday
# 16079        95880  6/14/2018                 1439          3  weekday
# 16080        95880  6/15/2018                 1440          4  weekday
# 16081        95880  6/16/2018                 1440          5  weekend
# 16082        95880  6/17/2018                 1440          6  weekend
# 16083        95880  6/18/2018                 1440          0  weekday
# 16084        95880  6/19/2018                 1370          1  weekday
#
#        BlueCars_taken_sum  BlueCars_returned_sum  Utilib_taken_sum  \
# 16075                  34                     32                 0
# ...

# %%
#Lets check the day_type column entries to best understand the periods

df["day_type"].unique()
# Out:
# array(['weekday', 'weekend'], dtype=object)

# %%
#Lets check the 	dayOfWeek column entries to best understand the periods

df["dayOfWeek"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
#Lets check the Postal code column entries to best understand the areas

df["Postal code"].unique()
# Out:
# array([75001, 75002, 75003, 75004, 75005, 75006, 75007, 75008, 75009,
#        75010, 75011, 75012, 75013, 75014, 75015, 75016, 75017, 75018,
#        75019, 75020, 75112, 75116, 78000, 78140, 78150, 91330, 91370,
#        91400, 92000, 92100, 92110, 92120, 92130, 92140, 92150, 92160,
#        92170, 92190, 92200, 92210, 92220, 92230, 92240, 92250, 92260,
#        92270, 92290, 92300, 92310, 92320, 92330, 92340, 92350, 92360,
#        92370, 92380, 92390, 92400, 92410, 92420, 92500, 92600, 92700,
#        92800, 93100, 93110, 93130, 93150, 93170, 93200, 93230, 93260,
#        93300, 93310, 93350, 93360, 93370, 93390, 93400, 93440, 93500,
#        93600, 93700, 93800, 94000, 94100, 94110, 94120, 94130, 94140,
#        94150, 94160, 94220, 94230, 94300, 94340, 94410, 94450, 94500,
#        94700, 94800, 95100, 95870, 95880])

# %%
#previewing  our column names
list(df.columns)
# Out:
# ['Postal code',
#  'date',
#  'n_daily_data_points',
#  'dayOfWeek',
#  'day_type',
#  'BlueCars_taken_sum',
#  'BlueCars_returned_sum',
#  'Utilib_taken_sum',
#  'Utilib_returned_sum',
#  'Utilib_14_taken_sum',
#  'Utilib_14_returned_sum',
#  'Slots_freed_sum',
#  'Slots_taken_sum']

# %% [markdown]
# #1.3 Classifying the columns into datatypes for univariate analysis

# %%
# Checking the structure of the dataset
df.shape  #(16085, 13)
#Checking the datatypes of the columns
df.info()
# we have 12 columns where "date" and "day_type" are Objects
# while the rest are intergers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16085 entries, 0 to 16084
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Postal code             16085 non-null  int64
#  1   date                    16085 non-null  object
#  2   n_daily_data_points     16085 non-null  int64
#  3   dayOfWeek               16085 non-null  int64
#  4   day_type                16085 non-null  object
#  5   BlueCars_taken_sum      16085 non-null  int64
#  6   BlueCars_returned_sum   16085 non-null  int64
#  7   Utilib_taken_sum        16085 non-null  int64
#  8   Utilib_returned_sum     16085 non-null  int64
#  9   Utilib_14_taken_sum     16085 non-null  int64
#  10  Utilib_14_returned_sum  16085 non-null  int64
#  11  Slots_freed_sum         16085 non-null  int64
#  12  Slots_taken_sum         16085 non-null  int64
# dtypes: int64(11), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# *The date's data type is wrongly matched. We will have to convert it to the appropriate data typ*e.

# %%
# We have to check the accuracy of the dataset in terms of the right datatype for each column
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16085 entries, 0 to 16084
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Postal code             16085 non-null  int64
#  1   date                    16085 non-null  datetime64[ns]
#  2   n_daily_data_points     16085 non-null  int64
#  3   dayOfWeek               16085 non-null  int64
#  4   day_type                16085 non-null  object
#  5   BlueCars_taken_sum      16085 non-null  int64
#  6   BlueCars_returned_sum   16085 non-null  int64
#  7   Utilib_taken_sum        16085 non-null  int64
#  8   Utilib_returned_sum     16085 non-null  int64
#  9   Utilib_14_taken_sum     16085 non-null  int64
#  10  Utilib_14_returned_sum  16085 non-null  int64
#  11  Slots_freed_sum         16085 non-null  int64
#  12  Slots_taken_sum         16085 non-null  int64
# dtypes: datetime64[ns](1), int64(11), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# *Only the day_type column contains the Categorical variable*

# %% [markdown]
# #1.4 Analysis of Categorical Variables

# %% [markdown]
# # 1.4.1 Frequency tables

# %%
#frequency table of day_type in the dataset
df.day_type.value_counts()
# Out:
# weekday    11544
# weekend     4541
# Name: day_type, dtype: int64

# %% [markdown]
# # 1.4.2 Bar Graphs & Pie Chart

# %%
# Bar graph for visualizing different data_type
df['day_type'].value_counts().head(10).plot.bar()

# %%
# Pie chart for visualizing different data_types
df['day_type'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)

# %% [markdown]
# # 1.5 Analysis of Numerical Variables

# %% [markdown]
# #1.5.1 Measures of Central Tendency

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16085 entries, 0 to 16084
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Postal code             16085 non-null  int64
#  1   date                    16085 non-null  datetime64[ns]
#  2   n_daily_data_points     16085 non-null  int64
#  3   dayOfWeek               16085 non-null  int64
#  4   day_type                16085 non-null  object
#  5   BlueCars_taken_sum      16085 non-null  int64
#  6   BlueCars_returned_sum   16085 non-null  int64
#  7   Utilib_taken_sum        16085 non-null  int64
#  8   Utilib_returned_sum     16085 non-null  int64
#  9   Utilib_14_taken_sum     16085 non-null  int64
#  10  Utilib_14_returned_sum  16085 non-null  int64
#  11  Slots_freed_sum         16085 non-null  int64
#  12  Slots_taken_sum         16085 non-null  int64
# dtypes: datetime64[ns](1), int64(11), object(1)
# memory usage: 1.6+ MB

# %%
# Finding mean of numerical values across the dataset

df["BlueCars_taken_sum"].mean()
df["BlueCars_returned_sum"].mean()
df["Utilib_taken_sum"].mean()
df["Utilib_returned_sum"].mean()
df["Utilib_14_taken_sum"].mean()
df["Utilib_14_returned_sum"].mean()
df["Slots_freed_sum"].mean()
df["Slots_taken_sum"].mean()
# Out:
# 22.629281939695367

# %%
# Finding mode of numerical values across the dataset

df["BlueCars_taken_sum"].mode()
df["BlueCars_returned_sum"].mode()
df["Utilib_taken_sum"].mode()
df["Utilib_returned_sum"].mode()
df["Utilib_14_taken_sum"].mode()
df["Utilib_14_returned_sum"].mode()
df["Slots_freed_sum"].mode()
df["Slots_taken_sum"].mode()
# Out:
# 0    0
# dtype: int64

# %% [markdown]
# # 1.6 Measures of Dispersion/Variability/Spread

# %%
# Finding the standard deviation of numerical data across the dataset

df["BlueCars_taken_sum"].std()
df["BlueCars_returned_sum"].std()
df["Utilib_taken_sum"].std()
df["Utilib_returned_sum"].std()
df["Utilib_14_taken_sum"].std()
df["Utilib_14_returned_sum"].std()
df["Slots_freed_sum"].std()
df["Slots_taken_sum"].std()
# Out:
# 52.146029870452566

# %%
# Finding the variance of numerical data across the dataset

df["BlueCars_taken_sum"].var()
df["BlueCars_returned_sum"].var()
df["Utilib_taken_sum"].var()
df["Utilib_returned_sum"].var()
df["Utilib_14_taken_sum"].var()
df["Utilib_14_returned_sum"].var()
df["Slots_freed_sum"].var()
df["Slots_taken_sum"].var()
# Out:
# 2719.2084312501315

# %%
# Finding the Quantiles of the numerical data across the dataset
 

df["BlueCars_taken_sum"].quantile([0.25,0.5,0.75])
df["BlueCars_returned_sum"].quantile([0.25,0.5,0.75])
df["Utilib_returned_sum"].quantile([0.25,0.5,0.75])
df["Utilib_14_taken_sum"].quantile([0.25,0.5,0.75])
df["Utilib_14_returned_sum"].quantile([0.25,0.5,0.75])
df["Slots_freed_sum"].quantile([0.25,0.5,0.75])
df["Slots_taken_sum"].quantile([0.25,0.5,0.75])
# Out:
# 0.25    0.0
# 0.50    0.0
# 0.75    5.0
# Name: Slots_taken_sum, dtype: float64

# %%
# Finding the Skeweness of the numerical data across the dataset
 
df["BlueCars_taken_sum"].skew()
df["BlueCars_returned_sum"].skew()
df["Utilib_taken_sum"].skew()
df["Utilib_returned_sum"].skew()
df["Utilib_14_taken_sum"].skew()
df["Utilib_14_returned_sum"].skew()
df["Slots_freed_sum"].skew()
df["Slots_taken_sum"].skew()
# Out:
# 2.5969043474634987

# %%
# Finding the Kurtosis of the numerical data across the dataset
 
df["BlueCars_taken_sum"].kurt()
df["BlueCars_returned_sum"].kurt()
df["Utilib_taken_sum"].kurt()
df["Utilib_returned_sum"].kurt()
df["Utilib_14_taken_sum"].kurt()
df["Utilib_14_returned_sum"].kurt()
df["Slots_freed_sum"].kurt()
df["Slots_taken_sum"].kurt()
# Out:
# 6.442553073772169

# %%
#Summary statistics

df.describe()
# Out:
#         Postal code  n_daily_data_points     dayOfWeek  BlueCars_taken_sum  \
# count  16085.000000         16085.000000  16085.000000        16085.000000
# mean   88791.293876          1431.330619      2.969599          125.926951
# std     7647.342000            33.212050      2.008378          185.426579
# min    75001.000000          1174.000000      0.000000            0.000000
# 25%    91330.000000          1439.000000      1.000000           20.000000
# 50%    92340.000000          1440.000000      3.000000           46.000000
# 75%    93400.000000          1440.000000      5.000000          135.000000
# max    95880.000000          1440.000000      6.000000         1352.000000
#
#        BlueCars_returned_sum  Utilib_taken_sum  Utilib_returned_sum  \
# count           16085.000000      16085.000000         16085.000000
# mean              125.912714          3.698290             3.699099
# std               185.501535          5.815058             5.824634
# ...

# %% [markdown]
# # 1.7 MORE UNIVARIATE AND BIVARIATE ANALYSIS AND VISUALIZATION OF DATA COLUMNS OF FOCUS

# %% [markdown]
# #1.7.1 Checking whether there is missing data

# %%
# Lets check for missing data

df.isnull().any()
# Out:
# Postal code               False
# date                      False
# n_daily_data_points       False
# dayOfWeek                 False
# day_type                  False
# BlueCars_taken_sum        False
# BlueCars_returned_sum     False
# Utilib_taken_sum          False
# Utilib_returned_sum       False
# Utilib_14_taken_sum       False
# Utilib_14_returned_sum    False
# Slots_freed_sum           False
# Slots_taken_sum           False
# dtype: bool

# %% [markdown]
# - *There are no missing data.- Since there are no missing values, there is no need for any  action.*

# %% [markdown]
# # 1.7.2 Checking for anomalies

# %%
# lets check whether we have duplicates in the dataset

df.duplicated().any()
# Out:
# False

# %% [markdown]
# - *There are no duplicates in the dataset.*

# %% [markdown]
# # 1.7.3 DATA CLEANING
# - *Lets rename the Postal code column*
# - *Since there are no missing values more action isnt      warranted*

# %%
# In checking for anomalies we do realize that the postal code column was has a spaces

df.rename(columns = {'Postal code': 'Postal_code'},inplace = True)

# %% [markdown]
# # 1.8 Visualization of univariate and bivariate data

# %%
# Lets visualize oneof the numerical data column
sns.boxplot(df.BlueCars_taken_sum)
plt.title('A boxplot of the BlueCars_taken_sum ')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.BlueCars_returned_sum)
plt.title('A boxplot of the BlueCars_returned_sum ')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 1.8.1 Checking range of the dataset

# %%
#Lets check the range of the data columns

Q1 =df.quantile(0.25)
Q3 =df.quantile(0.75)

Range = Q3 - Q1
display(Range)
# Out:
# Postal_code               2070.0
# n_daily_data_points          1.0
# dayOfWeek                    4.0
# BlueCars_taken_sum         115.0
# BlueCars_returned_sum      115.0
# Utilib_taken_sum             4.0
# Utilib_returned_sum          4.0
# Utilib_14_taken_sum          9.0
# Utilib_14_returned_sum       9.0
# Slots_freed_sum              5.0
# Slots_taken_sum              5.0
# dtype: float64

# %% [markdown]
# # 1.8.2 Correlation of between the dataset

# %%
# Lets preview the correlation in the dataset

df.corr(method = 'kendall')
# Out:
#                         Postal_code  n_daily_data_points  dayOfWeek  \
# Postal_code                1.000000             0.000470   0.000308
# n_daily_data_points        0.000470             1.000000   0.075970
# dayOfWeek                  0.000308             0.075970   1.000000
# BlueCars_taken_sum        -0.353530             0.038970   0.068257
# BlueCars_returned_sum     -0.354069             0.036629   0.061207
# Utilib_taken_sum          -0.346462             0.034399   0.049732
# Utilib_returned_sum       -0.347097             0.033156   0.046798
# Utilib_14_taken_sum       -0.341879             0.034703   0.055497
# Utilib_14_returned_sum    -0.341231             0.036055   0.050462
# Slots_freed_sum           -0.457003             0.012188   0.011057
# Slots_taken_sum           -0.457624             0.011151   0.009588
#
#                         BlueCars_taken_sum  BlueCars_returned_sum  \
# Postal_code                      -0.353530              -0.354069
# ...

# %% [markdown]
# #1.8.3  Bivariate analysis of our data of focus

# %% [markdown]
# THE CLUSTER SAMPLING METHOD ALSO USED.

# %% [markdown]
# - *we use cluster sampling because we can henceforth divide the population of the dataset into naturally occuring clusters where we can consider all elements of the randomly selected clusters i.e the bluecars cluster, the utilib cluster or individual postal code clusters randomly selected*

# %%
# Return rate of blue cars per dayof the week bar graph
df.groupby('dayOfWeek')['BlueCars_returned_sum'].sum().plot(kind='bar')
plt.xticks(rotation=0)
plt.title('Blue car return rate per day of the week')
# Out:
# Text(0.5, 1.0, 'Blue car return rate per day of the week')

# %%
# Sum of blue cars taken per days of the week bar graph
df.groupby('dayOfWeek')['BlueCars_taken_sum'].sum().plot(kind='bar')
plt.xticks(rotation=0)
plt.title('Blue car pick up rate per day of the week')
# Out:
# Text(0.5, 1.0, 'Blue car pick up rate per day of the week')

# %%
# Sum of Bluecars taken per postal code
bluecar_pickup = df.groupby(['Postal_code'])['BlueCars_taken_sum'].mean().sort_values(ascending=False)
bluecar_pickup.head(10)
# Out:
# Postal_code
# 75015    896.955128
# 75016    790.301282
# 75017    734.493590
# 75013    541.596154
# 75019    525.467949
# 75012    497.256410
# 75014    486.294872
# 75011    480.378205
# 75020    463.660256
# 75008    437.480769
# Name: BlueCars_taken_sum, dtype: float64

# %%
# Sum of bluecars returned per postal code
bluecar_dropoff = df.groupby(['Postal_code'])['BlueCars_returned_sum'].mean().sort_values(ascending=False)
bluecar_dropoff.head(10)
# Out:
# Postal_code
# 75015    897.070513
# 75016    789.884615
# 75017    734.237179
# 75013    541.339744
# 75019    525.788462
# 75012    497.352564
# 75014    486.006410
# 75011    480.448718
# 75020    464.134615
# 75008    437.147436
# Name: BlueCars_returned_sum, dtype: float64

# %%
# Histogram of the sum of Bluecars taken
plt.figure(figsize=(10,9))
plt.hist(df["BlueCars_taken_sum"],bins=15,color="green")
plt.title('A Distribution of the BlueCars_returned_sum')
plt.show()

# %%
# Histogram of sum of bluecars returned
plt.figure(figsize=(10,9))
plt.hist(df["BlueCars_returned_sum"],bins=15,color="grey")
plt.title('A Distribution of the BlueCars_returned_sum')
plt.show()

# %%
# Sum of Utilib cars taken per postal code
Utilib = df.groupby(['Postal_code'])['Utilib_taken_sum'].mean().sort_values(ascending=False)
Utilib.head(10)
# Out:
# Postal_code
# 75015    24.346154
# 75017    20.858974
# 75016    20.756410
# 75013    17.679487
# 75019    15.769231
# 75014    14.929487
# 75011    14.493590
# 75012    14.429487
# 75020    14.378205
# 75018    13.025641
# Name: Utilib_taken_sum, dtype: float64

# %%
# Sum of Utilib cars returned per postal code
Utilib_Returned = df.groupby(['Postal_code'])['Utilib_returned_sum'].mean().sort_values(ascending=False)
Utilib_Returned.head(10)
# Out:
# Postal_code
# 75015    24.346154
# 75017    20.865385
# 75016    20.756410
# 75013    17.679487
# 75019    15.769231
# 75014    14.948718
# 75011    14.487179
# 75020    14.416667
# 75012    14.410256
# 75018    13.057692
# Name: Utilib_returned_sum, dtype: float64

# %%
# Sum of freed slots per day of the week
Free_slots = df.groupby(['dayOfWeek'])['Slots_freed_sum'].mean().sort_values(ascending=False)
Free_slots.head(10)
# Out:
# dayOfWeek
# 5    27.833260
# 6    25.989006
# 4    22.960370
# 3    21.252205
# 2    20.869048
# 1    19.930174
# 0    19.807077
# Name: Slots_freed_sum, dtype: float64

# %%
# Sum of slots taken per day of the week
Used_slots = df.groupby(['dayOfWeek'])['Slots_taken_sum'].mean().sort_values(ascending=False)
Used_slots.head(10)
# Out:
# dayOfWeek
# 5    27.943979
# 6    26.000880
# 4    23.000440
# 3    21.174162
# 2    20.821429
# 1    19.876851
# 0    19.826453
# Name: Slots_taken_sum, dtype: float64

# %% [markdown]
# # **1.9 Choosing a smaller sample**

# %%
Autolib = df.sample(100)
display(Autolib)
# Out:
#        Postal_code       date  n_daily_data_points  dayOfWeek day_type  \
# 1542         75010 2018-06-02                 1440          5  weekend
# 15710        95100 2018-04-07                 1318          5  weekend
# 12698        93700 2018-02-13                 1440          1  weekday
# 9666         92700 2018-01-12                 1439          4  weekday
# 4139         91370 2018-03-29                 1440          3  weekday
# ...            ...        ...                  ...        ...      ...
# 8381         92360 2018-05-22                 1438          1  weekday
# 5961         92200 2018-02-06                 1439          1  weekday
# 13938        94150 2018-02-06                 1439          1  weekday
# 12811        93800 2018-01-01                 1440          0  weekday
# 5649         92170 2018-02-06                 1439          1  weekday
#
#        BlueCars_taken_sum  BlueCars_returned_sum  Utilib_taken_sum  \
# ...

# %%
# plotting a crosstab bar graph of the sum of slots freed and the slots takenfrom the choosen sample

pd.crosstab(Autolib['Slots_freed_sum'], Autolib['Slots_taken_sum']).plot(kind='bar', stacked=True, figsize=(12,10))

# %% [markdown]
# # **2.0 HYPOTHESIS TESTING**

# %% [markdown]
# # 2.1.1 Defining the question

# %% [markdown]
# Working as a Data Scientist for the Autolib electric car-sharing service company to investigate a claim about the blue cars from the provided Autolib dataset.
#
# In this hypothesis test, I set out to investigate:
#
# IS THE NUMBER OF CARS TAKEN IN POSTAL CODE 75015 DIFFERENT FROM THAT IN 75017

# %% [markdown]
# # 2.1.2 Step 1: Defining Ho and H1

# %% [markdown]
# Ho: Number of cars in postal code 75015 = Number of cars in postal code 75017
#
# H1:  Number of cars in postal code 75015 ≠ Number of cars in postal code 75017

# %% [markdown]
# # 2.1.3 Step 2: Setting Significance Level

# %% [markdown]
# α = 0.05

# %% [markdown]
# # 2.1.4 Step 3: Selecting the appropriate statistical test. The input is a binary classification. 75015 or 75017.

# %% [markdown]
# The type of variable is the 'response'
#
# Is the response - No.
# None of the postal codes depend on each other.
#
# Does it follow a normal distribution in both? Test to be done

# %%
df.rename(columns = {'Postal code': 'Postal_code'},inplace = True)

# %%
#75015 is the first postal code.
PostalOne = df.loc[(df.Postal_code == 75015)]
PostalOne.describe()
# Out:
#        Postal_code  n_daily_data_points   dayOfWeek  BlueCars_taken_sum  \
# count        156.0           156.000000  156.000000          156.000000
# mean       75015.0          1431.288462    2.967949          896.955128
# std            0.0            33.310661    2.014207          189.507625
# min        75015.0          1174.000000    0.000000           49.000000
# 25%        75015.0          1439.000000    1.000000          781.000000
# 50%        75015.0          1440.000000    3.000000          878.500000
# 75%        75015.0          1440.000000    5.000000         1001.250000
# max        75015.0          1440.000000    6.000000         1352.000000
#
#        BlueCars_returned_sum  Utilib_taken_sum  Utilib_returned_sum  \
# count             156.000000        156.000000           156.000000
# mean              897.070513         24.346154            24.346154
# std               187.025929          8.130908             8.407104
# ...

# %%
#75017 is the second postal code.
PostalTwo = df.loc[(df.Postal_code == 75017)]
PostalTwo.describe()
# Out:
#        Postal_code  n_daily_data_points   dayOfWeek  BlueCars_taken_sum  \
# count        156.0           156.000000  156.000000          156.000000
# mean       75017.0          1431.288462    2.967949          734.493590
# std            0.0            33.310661    2.014207          126.229821
# min        75017.0          1174.000000    0.000000           38.000000
# 25%        75017.0          1439.000000    1.000000          685.250000
# 50%        75017.0          1440.000000    3.000000          724.000000
# 75%        75017.0          1440.000000    5.000000          786.000000
# max        75017.0          1440.000000    6.000000          992.000000
#
#        BlueCars_returned_sum  Utilib_taken_sum  Utilib_returned_sum  \
# count             156.000000        156.000000           156.000000
# mean              734.237179         20.858974            20.865385
# std               134.335118          6.989807             6.971913
# ...

# %% [markdown]
# #2.2 **IMPLEMENTING THE SOLUTION**

# %%
#Import the necessary library

import scipy.stats as stats

# %%
stats.shapiro(PostalOne['BlueCars_taken_sum'])
# Out:
# (0.9231284260749817, 2.1654109616520145e-07)

# %% [markdown]
# - *Since the p-value is small, we reject the null hypothesis that the BlueCars_taken_sum is normally distributed. Therefore, we need to use a non-parametric test*.

# %% [markdown]
# # 2.2.1 Deciding of 1 or 2 Tailed -

# %% [markdown]
# A one-tailed test implies that the alternative hypothesis is a directional inequality (i.e., "greater than" or "less than"). Only use a one-tailed test if the intention of the experiment is based on a pre-stated suspicion of direction. Otherwise, always assume two-tailed (i.e., alternative hypothesis is "not equal").
#
# Thus - Two Tailed

# %%
# Finding the p- value and determining whether to reject or fail to reject the 
# null hypothesis.

stats.mannwhitneyu(PostalOne['BlueCars_taken_sum'],PostalTwo['BlueCars_taken_sum'])
# Out:
# MannwhitneyuResult(statistic=4734.5, pvalue=5.313439023634663e-21)

# %% [markdown]
# p-value < 0.05, so we Reject the Null Hypothesis.
#
# - *Therefore the number of cars in postal code 75015 ≠ Number of cars in postal code 7501*7

# %% [markdown]
# # 2.2.2 **Recommendations**

# %% [markdown]
# - The number of cars in postal code 75015 can be increased to meet the high demand in the area.
#
# - The Slots in areas with high demand should be increased to ensure that the increased cars find a slot.
#
# - The number of cars, especially on day 5 then 6, the weekends, should be increased.
