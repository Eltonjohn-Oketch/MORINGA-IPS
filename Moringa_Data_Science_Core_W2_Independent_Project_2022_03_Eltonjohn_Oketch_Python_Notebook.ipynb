# %% [markdown]
# ## WEEK 2 IP ELTONJOHN OKETCH (UNIVARIATE, BIVARIATE & MULTIVARIATE ANALYSIS)

# %% [markdown]
# ## 1.0 Importing Libraries

# %%
# Importing Pandas
import pandas as pd
# Importing Numpy
import numpy as np
# Importing Matplotlib
import matplotlib.pyplot as plt
# Importing Seaborn
import seaborn as sns

# %% [markdown]
# ## 1.1 Loading the dataset

# %%
# Step 1.1: Loading our Dataset

df= pd.read_csv("http://bit.ly/FinancialDataset")

# Previewing the dataset

df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %% [markdown]
# ### 1.2 UNIVARIATE ANALYSIS

# %%
df.head(3)
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
#
#                Level of Educuation           Type of Job
# 0              Secondary education         Self employed
# 1              No formal education  Government Dependent
# ...

# %%
df["country"].unique()
# Out:
# array(['Kenya', 'Rwanda', 'Tanzania', nan, 'Uganda'], dtype=object)

# %%
# This the analysis of one variable
# Lets split the dataset into individual countries
df_kenya = df[(df["country"]== "Kenya")]
df_rwanda = df[(df["country"]== "Rwanda")]
df_tanzania = df[(df["country"]== "Tanzania")]
df_uganda = df[(df["country"]== "Uganda")]

#Checking if the created dataset has met the criterion we need
df_kenya["country"].unique()
df_rwanda["country"].unique()
df_tanzania["country"].unique()
df_uganda["country"].unique()
# Out:
# array(['Uganda'], dtype=object)

# %%
#previewing  our column names
list(df.columns)
# Out:
# ['country',
#  'year',
#  'uniqueid',
#  'Has a Bank account',
#  'Type of Location',
#  'Cell Phone Access',
#  'household_size',
#  'Respondent Age',
#  'gender_of_respondent',
#  'The relathip with head',
#  'marital_status',
#  'Level of Educuation',
#  'Type of Job']

# %%
#Renaming Columns
df.rename(columns = {'Has a Bank account':'Has_a_Bank_account' ,
                     'Type of Location':'Type_of_Location', 'Cell Phone Access':'Cell_Phone_Access',
                     'Respondent Age':'Respondent_Age',
                     'The relathip with head':'The_relathip_with_head', 
                     'Level of Educuation':'Level_of_Educuation' ,'Type of Job':'Type_of_Job' }, inplace = True)
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Now lets preview the dataset with the new column names

list(df.columns)
# Out:
# ['country',
#  'year',
#  'uniqueid',
#  'Has_a_Bank_account',
#  'Type_of_Location',
#  'Cell_Phone_Access',
#  'household_size',
#  'Respondent_Age',
#  'gender_of_respondent',
#  'The_relathip_with_head',
#  'marital_status',
#  'Level_of_Educuation',
#  'Type_of_Job']

# %% [markdown]
# ## 1.3 Classifying the columns into datatypes for univariate analysis

# %%
# Checking the structure of the dataset
df.shape  #(23524, 13)
#Checking the datatypes of the columns
df.info()
# we have 13 columns where "household_size" and "Respondent Age" are Continous data
# while the rest are Categorical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has_a_Bank_account      23488 non-null  object
#  4   Type_of_Location        23509 non-null  object
#  5   Cell_Phone_Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent_Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The_relathip_with_head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level_of_Educuation     23495 non-null  object
#  12  Type_of_Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 1.4 Analysis of Categorical Variables

# %% [markdown]
# ## 1.4.1 Frequency tables

# %%
#First we will start by Creating Frequency table of column using the value_counts() function
#frequency table of Countries in the whole dataset
df.country.value_counts()
#Frequency table of years in the entire dataset
df.year.value_counts()
#Frequency table of uniqueids in the entire dataset
df.uniqueid.value_counts()
#Frequency table of people who have a Bank account in the entire dataset
df.Has_a_Bank_account.value_counts()
#Frequency table of Type of Location in the entire dataset
df.Type_of_Location.value_counts()
#Frequency table of people with CellPhone Access in the entire dataset
df.Cell_Phone_Access.value_counts()
#Frequency table of gender of respondent in the entire dataset
df.gender_of_respondent.value_counts()
#Frequency table of The relationdship with head in the entire dataset
df.The_relathip_with_head.value_counts()
#Frequency table of marital status in the entire dataset
df.marital_status.value_counts()
#Frequency table of Level of Educuation in the entire dataset
df.Level_of_Educuation.value_counts()
#Frequency table of Type of Job in the entire dataset
df.Type_of_Job.value_counts()
# Out:
# Self employed                   6428
# Informally employed             5587
# Farming and Fishing             5433
# Remittance Dependent            2524
# Other Income                    1080
# Formally employed Private       1055
# No Income                        627
# Formally employed Government     387
# Government Dependent             247
# Dont Know/Refuse to answer       126
# Name: Type_of_Job, dtype: int64

# %% [markdown]
# ## 1.5 Bar charts & Pie charts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has_a_Bank_account      23488 non-null  object
#  4   Type_of_Location        23509 non-null  object
#  5   Cell_Phone_Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent_Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The_relathip_with_head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level_of_Educuation     23495 non-null  object
#  12  Type_of_Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 1.5.1 Bar graphs

# %%
# Creating bar graphs for each categorical datatype column


# Bar graph for visualizing different countries
df['country'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different years
df['year'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different uniqueids
df['uniqueid'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different people who have a Bank account
df['Has_a_Bank_account'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different Type of Locations
df['Type_of_Location'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different CellPhone Access
df['Cell_Phone_Access'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different gender of respondent
df['gender_of_respondent'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different The relationship with head
df['The_relathip_with_head'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different marital status
df['marital_status'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different Level of Educuation
df['Level_of_Educuation'].value_counts().head(10).plot.bar()
# Bar graph for visualizing different Type of Jobs
df['Type_of_Job'].value_counts().head(10).plot.bar()

plt.xlabel('Categorical variable chosen')
plt.ylabel('Quantifiable number')
plt.title('A bar graph of categoracal data columns chosen')
plt.show()

# %% [markdown]
# # 1.5.2 Pie charts

# %%
# Creating pie charts for each categorical datatype column
# (N/B: UNCOMMENT EACH INDIVIDUAL PIE CHART SEPARATELY TO PERCIEVE THE DIFFERENCE)


# # Pie chart for visualizing different countries
# df['country'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different years
# df['year'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different uniqueids
# df['uniqueid'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different people who have a Bank account
# df['Has_a_Bank_account'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different Type of Locations
# df['Type_of_Location'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different CellPhone Access
# df['Cell_Phone_Access'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different gender of respondent
df['gender_of_respondent'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different The relationship with head
# df['The_relathip_with_head'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# Pie chart for visualizing different marital status
# df['marital_status'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different Level of Educuation
# df['Level_of_Educuation'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
# # Pie chart for visualizing different Type of Jobs
# df['Type_of_Job'].value_counts().head(10).plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)

# %% [markdown]
# ## 1.6 Analysis of Numerical Variables

# %% [markdown]
# ## 1.6.1 Measures of Central Tendency

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has_a_Bank_account      23488 non-null  object
#  4   Type_of_Location        23509 non-null  object
#  5   Cell_Phone_Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent_Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The_relathip_with_head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level_of_Educuation     23495 non-null  object
#  12  Type_of_Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 1.6.2 Finding Mean

# %%
# We only have two continous variables, this is the column  "household_size"
# and the column "Respondent_Age"

# Finding their mean
# Finding mean of Household sizes across the dataset

df["household_size"].mean()  #(3.6818181818181817)

# Finding mean of  Respondent Ages across the dataset

df["Respondent_Age"].mean()
# Out:
# 38.804299702000854

# %% [markdown]
# ## 1.6.3 Finding Mode

# %%
# Finding the mode

# Finding the mode of household sizes across the dataset

df["household_size"].mode() #(0    2.0)

# Finding mode of  Respondent Ages across the dataset

df["Respondent_Age"].mode()
# Out:
# 0    30.0
# dtype: float64

# %% [markdown]
# ## 1.6.4 Finding the Median

# %%
# Finding the median

# Finding the median of household sizes across the dataset

df["household_size"].median() #(3.0)

# Finding mode of  Respondent Ages across the dataset

df["Respondent_Age"].median()
# Out:
# 35.0

# %% [markdown]
# ## 1.7 Measures of Dispersion/Variability/Spread

# %% [markdown]
# ##1.7.1 Finding the standard deviation

# %%
# Finding the standard deviation

# Finding the standard deviation of household sizes across the dataset

df["household_size"].std() #(2.279933399631944)

# Finding standard deviation of  Respondent Ages across the dataset

df["Respondent_Age"].std()
# Out:
# 16.51999610879876

# %% [markdown]
# ## 1.7.2 Finding the Variance

# %%
# Finding the variance

# Finding the variance of household sizes across the dataset

df["household_size"].var() #(5.198096306757275)

# Finding variance of  Respondent Ages across the dataset

df["Respondent_Age"].var()
# Out:
# 272.9102714347262

# %% [markdown]
# ## 1.7.3 Finding the range

# %%
# Finding the range

# Finding the range of household sizes across the dataset

df1_max = df["household_size"].max()
df1_min = df["household_size"].min() 

# Calculating the range
df1_max - df1_min   #(21.0)

# Finding the range of Respondent Ages across the dataset

df2_max = df["Respondent_Age"].max()
df2_min = df["Respondent_Age"].min() 

# Calculating the range
df2_max - df2_min
# Out:
# 84.0

# %% [markdown]
# ## 1.7.4 Finding Quartiles

# %%
# Finding the quantiles of the continous data columns

# Finding the Quantiles of the Household_size dataset

df["household_size"].quantile([0.25,0.5,0.75])  #(0.25    2.0
                                                #0.50    3.0
                                                #0.75    5.0)

# Finding the Quantiles of the Household_size dataset

df["Respondent_Age"].quantile([0.25,0.5,0.75])
# Out:
# 0.25    26.0
# 0.50    35.0
# 0.75    49.0
# Name: Respondent_Age, dtype: float64

# %% [markdown]
# ## 1.7.5 Finding Skeweness

# %%
# Finding the Skeweness

# Finding the Skeweness of household sizes across the dataset

df["household_size"].skew() #(0.977652354434429)

# Finding Skeweness of  Respondent Ages across the dataset

df["Respondent_Age"].skew()

#The household_size and the Respondent_Age are positively skewed 
# therefore their means are greator than their individual modes as confirmed above
# Out:
# 0.8418012375387167

# %% [markdown]
# ## 1.7.6 Finding Kurtosis

# %%
# Finding the Kurtosis

# Finding the Kurtosis of household sizes across the dataset

df["household_size"].kurt() #(1.1581542795310726)

#The household_sizes has a heavy tail since its Kurtosis is greator than zero
# hence it has a heavy tail and is known as leptokurtic distribution.
# This indicates possible outliers within that column

# Finding Kurtosis of  Respondent Ages across the dataset

df["Respondent_Age"].kurt()

#The Respondent_Age has a normal tail since its Kurtosis is closer to zero
# hence it  known as mesokurtic distribution. (no outliers)
# Out:
# 0.10110811880734305

# %% [markdown]
# ## 1.7.7 Summary Statistics

# %%
#  Displaying the summary statistics of the dataset

# summary statistics for the Household_size column
df['household_size'].describe()

# summary statistics for the Respondent_Age column
df['Respondent_Age'].describe()
# Out:
# count    23490.000000
# mean        38.804300
# std         16.519996
# min         16.000000
# 25%         26.000000
# 50%         35.000000
# 75%         49.000000
# max        100.000000
# Name: Respondent_Age, dtype: float64

# %% [markdown]
# ## 1.8 Visualization Technique for Contionous variables

# %% [markdown]
# ## 1.8.1 A BoxPLot

# %%
# Creating the boxplot
#
# Creating a boxplot of Household_size column

sns.boxplot(df["household_size"], showmeans=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Creating a boxplot of Respondent_Age column

sns.boxplot(df["Respondent_Age"], showmeans=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## 1.8.2 A Histogram

# %%
# Plotting the histogram

# Creating a histogram of Household_size column

df["household_size"].hist()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram of Household_size') 
plt.show()

# %%
# Plotting the histogram

# Creating a histogram of Respondent_Age column

df["Respondent_Age"].hist()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram of Respondent_Age') 
plt.show()

# %% [markdown]
# ## 2.0 EXPLORATORY DATA ANALYSIS: (Univariate Analysis)

# %% [markdown]
# #2.1 Defining the question

# %% [markdown]
# #a) Specifying the question

# %% [markdown]
# - Which gender is more likely to have a bank account for persons aged 20 and above

# %% [markdown]
# #b) Defining the Metric for Success

# %% [markdown]
# *1.)The E.D.A will be a success if we can fruitfully known which gender is likely to have a bank account for persond aged 20 and above*
#
# *2.)The E.D.A will be a success if we can measure which different gender demographics from the dataset*
#
# *3.)The E.D.A will be a success if we can filter the previous result to persons aged 20 and above.*
#
# *4.)The E.D.A will be a success if we can visualize our outcome to paint a picture of which gender has more percentage.*

# %% [markdown]
# # c) Understanding the context

# %% [markdown]
# *We have available a dataset of persons with access to a bank account and their respective ages well stated*

# %% [markdown]
# #d) Recording the Experimental Design

# %% [markdown]
# *1.) The best way to answer our question is by first previewing our dataset to check whether we have the right data that contains the persons with access to bank accounts and their respective ages*
#
# *2.) We will be measuring the gender with the most bank accounts with ages above 20*
#
# *3.) The right data will be given for this analysis and that data should meet the first criterion stated above.*
#
# *4.) The libraries to be used will be those that can facilitate univariate analysis that is the pandas library, the numpy library  ,seaborn library and the matplotlib library.*

# %% [markdown]
# #e) Data Relevance

# %% [markdown]
# *The relevance of the findings of this analysis will be that we will be able toknow which gender to most focuss on as they represent majority of bank account holders*

# %% [markdown]
# #2.1 Reading the dataset

# %%
#First we load the relevant libraries

# Importing Pandas
import pandas as pd
# Importing Numpy
import numpy as np
# Importing Seaborn
import seaborn as sns
# Importing Matplotlib
import matplotlib.pyplot as plt

# we already read our dataset during univariate analysis

# %% [markdown]
# #2.2 Checking the data

# %%
# Determining the no. of records in our dataset
#
df.shape
# Out:
# (23524, 13)

# %%
# Previewing the top of our dataset
#
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the bottom of our dataset
# 
df.tail()
# Out:
#       country  year       uniqueid Has_a_Bank_account Type_of_Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The_relathip_with_head        marital_status  Level_of_Educuation  \
# ...

# %%
# Checking whether each column has an appropriate datatype
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has_a_Bank_account      23488 non-null  object
#  4   Type_of_Location        23509 non-null  object
#  5   Cell_Phone_Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent_Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The_relathip_with_head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level_of_Educuation     23495 non-null  object
#  12  Type_of_Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 2.3 External source validation

# %% [markdown]
# #a) Validation

# %%
# This data is part of collected responses from people in Rwanda, Kenya, uganda and Tanzania
# according to external sources, These countriesmake up the east african community
# therefore it is safe to assume that this dataset represents truth as these countrie
# are somewhat involved in trade and shared resources.
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %% [markdown]
# # 2.4 Tidying the dataset

# %%
# Checking for Outliers

sns.boxplot(df["Respondent_Age"], showmeans=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df["Respondent_Age"].kurt()

#The Respondent_Age has a normal tail since its Kurtosis is closer to zero
# hence it  known as mesokurtic distribution. (no outliers)
# Out:
# 0.10110811880734305

# %% [markdown]
# - *The column for age has no  outliers because the Kurtosis is closer to zero*

# %%
# Checking for Anomalies
#
df.duplicated().any()
# Out:
# False

# %% [markdown]
# - *No duplicated data*

# %%
# Identifying the Missing Data
#
df.isnull().any()
# Out:
# country                    True
# year                      False
# uniqueid                  False
# Has_a_Bank_account         True
# Type_of_Location           True
# Cell_Phone_Access          True
# household_size             True
# Respondent_Age             True
# gender_of_respondent       True
# The_relathip_with_head     True
# marital_status             True
# Level_of_Educuation        True
# Type_of_Job                True
# dtype: bool

# %% [markdown]
# - *The dataset has missing values*

# %%
# Dealing with the Missing Data
#

df.dropna( inplace= True)
df.isnull().any()
# Out:
# country                   False
# year                      False
# uniqueid                  False
# Has_a_Bank_account        False
# Type_of_Location          False
# Cell_Phone_Access         False
# household_size            False
# Respondent_Age            False
# gender_of_respondent      False
# The_relathip_with_head    False
# marital_status            False
# Level_of_Educuation       False
# Type_of_Job               False
# dtype: bool

# %% [markdown]
# - *I dropped all the missing values*

# %% [markdown]
# # 2.5 Exploratoty Analysis

# %%
#Lets preview what we have now 

df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
df['Has_a_Bank_account'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['gender_of_respondent'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Ploting the univariate summaries and recording our observations
#

# Frequency table

#Frequency table of gender of respondent in the entire dataset
df.gender_of_respondent.value_counts()
# Out:
# Female    13767
# Male       9576
# Name: gender_of_respondent, dtype: int64

# %%
# Bar graph for visualizing different gender of respondent

df['gender_of_respondent'].value_counts().head(10).plot.bar(color="green")

plt.ylabel("y")
plt.xlabel(" x")
plt.title("Bar graph of Gender of respondents")
plt.show()

# %%
# # Pie chart for visualizing different gender of respondent
explode = (0.1 ,0)
df['gender_of_respondent'].value_counts().head(10).plot.pie(explode = explode,autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie of gender of respondents')
plt.show()

# %% [markdown]
# #2.6 Implementing the Solution

# %%
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Implementing the Solution
# 
df1 = df[(df["Has_a_Bank_account"] == "Yes")]
df1.head()
df2 = df1[(df1["Respondent_Age"] >= 20.0)]
df2.head()

#Frequency table of data with our solution
df2.gender_of_respondent.value_counts()
# Out:
# Male      1785
# Female    1448
# Name: gender_of_respondent, dtype: int64

# %% [markdown]
# - *The gender with the most access to commercial bank accounts, aged 20 and above are males*

# %%
#Lets display our solution using visuals
# Pie chart for visualizing different gender of respondent of people with access to bank accounts aged 20 and above
explode = (0.1 ,0)
df2['gender_of_respondent'].value_counts().head(10).plot.pie(explode = explode,autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie of gender of respondents')
plt.show()

# %%
# Bar graph for visualizing different gender of respondent of people with access to bank accounts aged 20 and above

df2['gender_of_respondent'].value_counts().head(10).plot.bar(color="grey")

plt.ylabel("y")
plt.xlabel(" x")
plt.title("Bar graph of Gender of respondents")
plt.show()

# %% [markdown]
# ## 2.7 Challenging the solution

# %%
# The population of all the four countries have more females than males. I would
# have expected more females to have more bank accounts than the males. The solution
# too might be flawed because it cuts across different years and different countries. 
# This is only a reflection of the respondents who took part in the survey and not
# the actual fact of the matter.

# %% [markdown]
# # 2.8 Follow up questions

# %% [markdown]
# #a) Did we have the right data?

# %% [markdown]
# - *yes we did have the right data that made the discovery of the solution possible. It had the right data columns with the right datatypes.*

# %% [markdown]
# #b) Do we need other data to answer our question?**bold text**

# %% [markdown]
# - *No we dont, as our question has already been answered.*

# %% [markdown]
# ## 3.0 BIVARIATE ANALYSIS

# %%
#Because we had already loaded our dataset, lets preview the datatype we have so
# that we can start our bivariate analysis

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23343 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23343 non-null  object
#  1   year                    23343 non-null  int64
#  2   uniqueid                23343 non-null  object
#  3   Has_a_Bank_account      23343 non-null  object
#  4   Type_of_Location        23343 non-null  object
#  5   Cell_Phone_Access       23343 non-null  object
#  6   household_size          23343 non-null  float64
#  7   Respondent_Age          23343 non-null  float64
#  8   gender_of_respondent    23343 non-null  object
#  9   The_relathip_with_head  23343 non-null  object
#  10  marital_status          23343 non-null  object
#  11  Level_of_Educuation     23343 non-null  object
#  12  Type_of_Job             23343 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.5+ MB

# %% [markdown]
# #3.1 Numerical and Numerical datatype Columns

# %%
# The only numerical data we have are of respondent age and the household size

# %% [markdown]
# #3.1.1 Scatterplots

# %%
# Previewing our dataset
df.head()

# Plotting our scatterplot
plt.scatter(df['household_size'], df['Respondent_Age'])

# Giving our scatterplot a title
plt.title('household_size vs Respondent_Age')

# Labelling our x axis
plt.xlabel('household_size')

# Labelling our y axis
plt.ylabel('Respondent_Age')

# Displaying our scatterplot
plt.show()

# There is no relation because the points are scattered throughout the graph.

# %% [markdown]
# # 3.1.2 Pearson Correlation coefficient

# %%
# Calculating the pearson coefficient

df["household_size"].corr(df["Respondent_Age"])
# Out:
# -0.11970919507762415

# %% [markdown]
# - *A negative (inverse) correlation occurs when the correlation coefficient is less than 0 and indicates that both variables move in the opposite direction. If respondent's age increases the househole size decreases and vice versa*
# - *This or that the two variable have no linear relationship at all because the correlation value is close to -0.1*
# - *If not the the two variables have a weak negative correlation between them but ill say that there exist no linear relationshio between the two variables*

# %% [markdown]
# # 3.2 Categorical and Numerical

# %% [markdown]
# # 3.2.1 Line Charts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23343 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23343 non-null  object
#  1   year                    23343 non-null  int64
#  2   uniqueid                23343 non-null  object
#  3   Has_a_Bank_account      23343 non-null  object
#  4   Type_of_Location        23343 non-null  object
#  5   Cell_Phone_Access       23343 non-null  object
#  6   household_size          23343 non-null  float64
#  7   Respondent_Age          23343 non-null  float64
#  8   gender_of_respondent    23343 non-null  object
#  9   The_relathip_with_head  23343 non-null  object
#  10  marital_status          23343 non-null  object
#  11  Level_of_Educuation     23343 non-null  object
#  12  Type_of_Job             23343 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.5+ MB

# %%
#Making of our line graphs 

years = df["year"]
household_size = df["household_size"]

# Plotting our line graph
plt.plot(years, household_size)

# Giving a title to our line graph
plt.title("years vs household_size", fontsize=14, y=1.015)

# Labelling the y-axis
plt.ylabel('household_size')

# Labelling the x-axis
plt.xlabel('years')

# Displaying our graph
plt.show()

# %%
#Making of our line graphs 

years = df["year"]
Respondent_Age = df["Respondent_Age"]

# Plotting our line graph
plt.plot(years, Respondent_Age)

# Giving a title to our line graph
plt.title("years vs Respondent_Age", fontsize=14, y=1.015)

# Labelling the y-axis
plt.ylabel('Respondent_Age')

# Labelling the x-axis
plt.xlabel('years')

# Displaying our graph
plt.show()

# %% [markdown]
# ##4.0 EXPLORATORY DATA ANALYSIS: Bivariate Analysis

# %% [markdown]
# #4.1.1 Defining the Question

# %% [markdown]
# #a) Specifying the Data Analytic Question

# %% [markdown]
# - *Determine relationship between Household size and the respondent's age.*

# %% [markdown]
# #b) Defining the Metric for Success

# %% [markdown]
# - *We will be successful if we can identify a relationship (a linear relationship either positive or negative) between the variable of household size and the resondent's age*

# %% [markdown]
# #c) Understanding the context

# %% [markdown]
# - *The context is to check the if there exist any correlation between household size and the respondent's age*

# %% [markdown]
# #d) Recording the Experimental Design

# %% [markdown]
# - *First we need to check the pearson coefficient between the two dataset.*
# - *Second we need to create a scatter plot to identify whether we have an existant relatoonship between the two variables being compared.*

# %% [markdown]
# #e) Data Relevance

# %% [markdown]
# - *The dataset we had indeed did have all the data we needed to make the bivariate analysis of the two variables*
# - *Also this helps us identify whether the two variables have a linear relation this can be helpful when doing the PCA analysis.*

# %% [markdown]
# #4.1.2 Checking the Data

# %%
# Determining the no. of records in our dataset
df.shape
# Out:
# (23343, 13)

# %%
# Previewing the top of our dataset
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the bottom of our dataset
df.tail()
# Out:
#       country  year       uniqueid Has_a_Bank_account Type_of_Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The_relathip_with_head        marital_status  Level_of_Educuation  \
# ...

# %%
# Checking whether each column has an appropriate datatype
df.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# Has_a_Bank_account         object
# Type_of_Location           object
# Cell_Phone_Access          object
# household_size            float64
# Respondent_Age            float64
# gender_of_respondent       object
# The_relathip_with_head     object
# marital_status             object
# Level_of_Educuation        object
# Type_of_Job                object
# dtype: object

# %% [markdown]
# #4.1.3 External Data Source Validation

# %% [markdown]
# ### a.Validation

# %%
# This data is part of collected responses from people in Rwanda, Kenya, uganda and Tanzania
# according to external sources, These countriesmake up the east african community
# therefore it is safe to assume that this dataset represents truth as these countrie
# are somewhat involved in trade and shared resources.
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %% [markdown]
# #4.1.4 Tidying the Dataset

# %%
# Checking for Outliers
fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 7))
fig.suptitle('Boxplots')
sns.boxplot(df["Respondent_Age"], ax=ax1)
sns.boxplot(df["household_size"], ax=ax2)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Checking for Anomalies
#
q1_HS = df['household_size'].quantile(.25)
q3_HS = df['household_size'].quantile(.75)

iqr_HS = q3_HS - q1_HS


q1_RA = df['Respondent_Age'].quantile(.25)
q3_RA = df['Respondent_Age'].quantile(.75)

iqr_RA = q3_RA - q1_RA

# Or

q1_3, q3_3 = np.percentile(df['household_size'], [25, 75]) 

iqr = q3_3 - q1_3

l_bound = q1_RA - (1.5*iqr)
u_bound = q3_3 + (1.5 * iqr)

print(iqr_HS, iqr)
# Out:
# 3.0 3.0

# %%
# Identifying the Missing Data
#
df.isnull().any()
# Out:
# country                   False
# year                      False
# uniqueid                  False
# Has_a_Bank_account        False
# Type_of_Location          False
# Cell_Phone_Access         False
# household_size            False
# Respondent_Age            False
# gender_of_respondent      False
# The_relathip_with_head    False
# marital_status            False
# Level_of_Educuation       False
# Type_of_Job               False
# dtype: bool

# %% [markdown]
# - *There is no missing data,I already handled missing data in the first E.D.A.*

# %% [markdown]
# # 4.1.5 Exploratory Analysis

# %%
# Ploting the bivariate summaries and recording our observations
sns.pairplot(df)
plt.show()

# %%
# Creating a heatmap
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #4.1.6 Implementing the Solution

# %%
#Determining if there is a relationship between the two variables

df["household_size"].corr(df["Respondent_Age"])
# Out:
# -0.11970919507762415

# %% [markdown]
# - *The two variables have no linear relationship at all because the correlation value is close to -0.1
# If not the the two variables have a weak negative correlation between them but i'll say that there exist no linear relationshio between the two variables*

# %%
#Lets create a scatter plot visual of the two variables
# Previewing our dataset
df.head()

# Plotting our scatterplot
plt.scatter(df['household_size'], df['Respondent_Age'])

# Giving our scatterplot a title
plt.title('household_size vs Respondent_Age')

# Labelling our x axis
plt.xlabel('household_size')

# Labelling our y axis
plt.ylabel('Respondent_Age')

# Displaying our scatterplot
plt.show()

# There is no relation because the points are scattered throughout the graph.

# %% [markdown]
# #4.1.7 Challenging your solution

# %% [markdown]
# - *I did plot the scatter plot to challenge the solution from the pearson correlation coefficient that suggested either weak or no correlation between the two variables in study. The scatter plot further quantified the frist finding as we see an extremely weak or no linear relationship between the two variables.*

# %% [markdown]
# # 4.1.8 Follow up questions

# %% [markdown]
# #a). Did we have the right data?

# %% [markdown]
# - *Yes we did. The data we have has all the value necessary to give the solution to the question we posed.*

# %% [markdown]
# #b). Do we need other data to answer our question?

# %% [markdown]
# - *Our data was self sufficient and we do not need any other datasets. But to get a more acurate depiction of the facts. The sample size has to be increased further.*

# %% [markdown]
# #c). Did we have the right question?

# %% [markdown]
# - Yeah we did have the right question as the question we had allowed us to do a comprehensive bivariate analysis of the dataset.

# %% [markdown]
# ## 5. MULTIVARIATE ANALYSIS with Python: Linear Discriminant Analysis(LDA)

# %%
#Lets preview the dataset
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# The first step is to divide datasetinto features and corresponding labels and 
# then divide the resultant dataset into training and test sets. 
# The following code divides data into labels and feature set. 
# The code assigns the first four columns of the dataset i.e. the feature set to X variable 
# while the values in the fifth column (labels) are assigned to the y variable

#Lets check how many columns we have
# df.shape #(13)
#Lets check which will be the predicted variable
# df.info() #(column 4 -This column has bank account which is our main focuss)
#lets now proceed
X = df.iloc[:, 6:7].values
y = df.iloc[:, 3].values
y
# Out:
# array(['Yes', 'No', 'Yes', ..., 'No', 'No', 'No'], dtype=object)

# %%
# Then the following code divides data into training and test sets
#
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Feature scaling
# We now need to perform feature scaling. We execute the following code to do so:
# 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#  Peforming LDA
# It requires only four lines of code to perform LDA with Scikit-Learn. 
# The LinearDiscriminantAnalysis class of the sklearn.discriminant_analysis 
# library can be used to Perform LDA in Python. 
#

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
# Training and Making Predictions
# We will use the random forest classifier to evaluate the performance of a PCA-reduced algorithms as shown
# 

from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
# Evaluating the Performance
# As always, the last step is to evaluate performance of the algorithm 
# with the help of a confusion matrix and find the accuracy of the prediction.
# 

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy' + str(accuracy_score(y_test, y_pred)))
# Out:
# [[4008    0]
#  [ 661    0]]
# Accuracy0.8584279288926965

# %% [markdown]
# - *My algorithm was able to to achieve an 85% accuracy,this means more variable were needed to improve this algorithm.*

# %% [markdown]
# #6.0 Multivariate Analysis (EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# #1. Defining the Question

# %% [markdown]
# #a) Specifying the Data Analytic Question

# %% [markdown]
# - *With what accuracy can you show how the dataset variables can predict which individuals likely to have a commercial bank account using the LDA algoritms*

# %% [markdown]
# #b) Defining the Metric for Success

# %% [markdown]
# - *If we can have a percentage above 80% then we would have achieved success after conducting our EDA analysis.*

# %% [markdown]
# #c) Understanding the context

# %% [markdown]
# - *The context is that our main question or the dependent variable has been the column has_a_bank_account and the rest of the column has been the independent variables.We are tasked with coming up with an algorithm that can predict if an individual will likely have a bank account by analysing the independent variables.*

# %% [markdown]
# #d) Recording the Experimental Design

# %% [markdown]
# - *First step is to divide dataset into features and corresponding labels and then divide the resultant dataset into training and test sets.*
# - *Second we need to perform feature scaling.*
# - *Third we Perform Linear Discriminant Analysis.*
# - *Fourth we do Training and Making Predictions*
# - *Lastly we evaluate the Performance*

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# - *The research problem is to figure out how we can predict which individuals are most likely to have or use a bank account. Your solution will help provide an indication of the state of financial inclusion in Kenya, Rwanda, Tanzania, and Uganda, while providing insights into some of the key demographic factors that might drive individuals’ financial outcomes.*

# %% [markdown]
# #6.2 Checking the data

# %%
# Determining the no. of records in our dataset
#
df.shape
# Out:
# (23343, 13)

# %%
# Previewing the top of our dataset
#
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the bottom of our dataset
# 
df.tail()
# Out:
#       country  year       uniqueid Has_a_Bank_account Type_of_Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The_relathip_with_head        marital_status  Level_of_Educuation  \
# ...

# %%
# Checking whether each column has an appropriate datatype
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23343 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23343 non-null  object
#  1   year                    23343 non-null  int64
#  2   uniqueid                23343 non-null  object
#  3   Has_a_Bank_account      23343 non-null  object
#  4   Type_of_Location        23343 non-null  object
#  5   Cell_Phone_Access       23343 non-null  object
#  6   household_size          23343 non-null  float64
#  7   Respondent_Age          23343 non-null  float64
#  8   gender_of_respondent    23343 non-null  object
#  9   The_relathip_with_head  23343 non-null  object
#  10  marital_status          23343 non-null  object
#  11  Level_of_Educuation     23343 non-null  object
#  12  Type_of_Job             23343 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.0+ MB

# %% [markdown]
# #6.3 External Data Source Validation

# %% [markdown]
# #a) Validation

# %%
# This data is part of collected responses from people in Rwanda, Kenya, uganda and Tanzania
# according to external sources, These countriesmake up the east african community
# therefore it is safe to assume that this dataset represents truth as these countrie
# are somewhat involved in trade and shared resources.
df.head()
# Out:
#   country  year    uniqueid Has_a_Bank_account Type_of_Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell_Phone_Access  household_size  Respondent_Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The_relathip_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %% [markdown]
# #6.4 Tidying the dataset

# %%
# Checking for Outliers
## Checking for Outliers
fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 7))
fig.suptitle('Boxplots')
sns.boxplot(df["Respondent_Age"], ax=ax1)
sns.boxplot(df["household_size"], ax=ax2)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Checking for Anomalies
#
# Checking for Anomalies
#
q1_HS = df['household_size'].quantile(.25)
q3_HS = df['household_size'].quantile(.75)

iqr_HS = q3_HS - q1_HS


q1_RA = df['Respondent_Age'].quantile(.25)
q3_RA = df['Respondent_Age'].quantile(.75)

iqr_RA = q3_RA - q1_RA

# Or

q1_3, q3_3 = np.percentile(df['household_size'], [25, 75]) 

iqr = q3_3 - q1_3

l_bound = q1_RA - (1.5*iqr)
u_bound = q3_3 + (1.5 * iqr)

print(iqr_HS, iqr)
# Out:
# 3.0 3.0

# %%
# Identifying the Missing Data
#
df.isnull().any()
# Out:
# country                   False
# year                      False
# uniqueid                  False
# Has_a_Bank_account        False
# Type_of_Location          False
# Cell_Phone_Access         False
# household_size            False
# Respondent_Age            False
# gender_of_respondent      False
# The_relathip_with_head    False
# marital_status            False
# Level_of_Educuation       False
# Type_of_Job               False
# dtype: bool

# %% [markdown]
# - *There are no more null values, we cleaned them all earlier.*

# %% [markdown]
# #6.5 Exploratory Analysis

# %%
# Ploting the bivariate summaries and recording our observations
sns.pairplot(df)
plt.show()

# %% [markdown]
# #7.0 Implementing the solution

# %%
# The first step is to divide datasetinto features and corresponding labels and 
# then divide the resultant dataset into training and test sets. 
# The following code divides data into labels and feature set. 
# The code assigns the first four columns of the dataset i.e. the feature set to X variable 
# while the values in the fifth column (labels) are assigned to the y variable

#Lets check how many columns we have
# df.shape #(13)
#Lets check which will be the predicted variable
# df.info() #(column 4 -This column has bank account which is our main focuss)
#lets now proceed
X = df.iloc[:, 6:7].values
y = df.iloc[:, 3].values
y

# Then the following code divides data into training and test sets
#
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Feature scaling
# We now need to perform feature scaling. We execute the following code to do so:
# 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#  Peforming LDA
# It requires only four lines of code to perform LDA with Scikit-Learn. 
# The LinearDiscriminantAnalysis class of the sklearn.discriminant_analysis 
# library can be used to Perform LDA in Python. 
#

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)


# Training and Making Predictions
# We will use the random forest classifier to evaluate the performance of a PCA-reduced algorithms as shown
# 

from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# Evaluating the Performance
# As always, the last step is to evaluate performance of the algorithm 
# with the help of a confusion matrix and find the accuracy of the prediction.
# 

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy' + str(accuracy_score(y_test, y_pred)))
# Out:
# [[4008    0]
#  [ 661    0]]
# Accuracy0.8584279288926965

# %% [markdown]
# - *Our algorithm has an accuracy of 85% when it come to the prediction of which individual is likely to have a commercial bank account based on the analysis of the independent variables.*

# %% [markdown]
# #7.1 Challenging the solution

# %% [markdown]
# - *More variables were needed to be included to improve the accuracy of the algorithm when it comes to the predicction.*

# %% [markdown]
# #7.2 Follow up questions

# %% [markdown]
# #a). Did we have the right data?

# %% [markdown]
# - *Yes we had the right dataset as the algorithm worked and was able to predict the dependent variable using the independent variables.*

# %% [markdown]
# #b). Do we need other data to answer our question?

# %% [markdown]
# - *No we did not need any other dataset, but more variables would have improve the accuracy of the algorithm.*

# %% [markdown]
# #c). Did we have the right question?

# %% [markdown]
# - *Yes we did indeed have the right question because we could make a prediction without going over the scopes of the question.*
